# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# #My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# #**Muhammad Rafique**
# MBU Lead (JAZZ)

# %% [markdown]
# *I am interested in data science because i have good understanding of Math,Stat,AI,CS and my education and work experience is related to this field. Also I am curious,judgemental and argumentative and want to become a good data scientist.*

# %% [markdown]
# ###Following code represents the addition of two numbers###

# %%
9+9
# Out:
# 18

# %% [markdown]
# * 1
# * 2
# * 3

# %% [markdown]
# 1.   Mangoes
# 2.   Grapes

# %% [markdown]
# ![new-jazz-logo-D69BD35771-seeklogo.com.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# www.jazz.com.pk
